# %%
import pandas as pd
import os

# %%
events=pd.read_json("../../simulation.jsonlines", orient="records",lines=True)
planes=pd.read_json("../../plans.jsonlines", orient="records",lines=True)

# %%
events
# Out:
# Error cuadrático medio (MSE) del modelo de tiempo de viaje de los camiones: 1.2255864341847125e-19

# %%
planes["trucks"][2]
# Out:
# [{'items': ['62',
#    '63',
#    '69',
#    '70',
#    '71',
#    '21',
#    '22',
#    '80',
#    '81',
#    '82',
#    '83',
#    '18',
#    '52',
#    '53',
#    '54',
#    '55',
#    '58',
#    '59',
#    '60',
#    '61',
#    '24',
#    '64',
#    '65',
#    '66',
#    '56',
#    '57',
#    '48',
#    '49',
#    '50',
#    '51'],
#   'route': [{'destination': '1dc4f91ead5dc8bbc8827a84',
#     'duration': 191,
#     'origin': 'ce6feed06bc1a9e5aff95f04'},
#    {'destination': '4dbe150beb9017467180616a',
#     'duration': 228,
#     'origin': '1dc4f91ead5dc8bbc8827a84'},
#    {'destination': '3dadeff0264ac5d0a622ab4d',
#     'duration': 603,
#     'origin': '4dbe150beb9017467180616a'},
#    {'destination': 'cd60a57f507bb50284b2531a',
#     'duration': 299,
#     'origin': '3dadeff0264ac5d0a622ab4d'},
#    {'destination': '87014c7222971cf09ce96d23',
#     'duration': 639,
#     'origin': 'cd60a57f507bb50284b2531a'},
#    {'destination': 'aa1d6225a535cb71907534c9',
#     'duration': 174,
#     'origin': '87014c7222971cf09ce96d23'},
#    {'destination': 'bcae7ac3a2483e26daf8d7c9',
#     'duration': 2261,
#     'origin': 'aa1d6225a535cb71907534c9'},
#    {'destination': '1b4d7b6abf2bd2180f8adbc1',
#     'duration': 2625,
#     'origin': 'bcae7ac3a2483e26daf8d7c9'},
#    {'destination': 'e1533363f8b02ef662b601f5',
#     'duration': 1603,
#     'origin': '1b4d7b6abf2bd2180f8adbc1'},
#    {'destination': 'e2ac4af1595838f724fa0184',
#     'duration': 780,
#     'origin': 'e1533363f8b02ef662b601f5'},
#    {'destination': 'c1337f1e9bfa6b7ff4ca5436',
#     'duration': 599,
#     'origin': 'e2ac4af1595838f724fa0184'},
#    {'destination': 'ce6feed06bc1a9e5aff95f04',
#     'duration': 735,
#     'origin': 'c1337f1e9bfa6b7ff4ca5436'}],
#   'truck_id': '5534TPH'},
#  {'items': ['8', '41'],
#   'route': [{'destination': '105c3a32b2007a715daf7c56',
#     'duration': 25,
#     'origin': 'ce6feed06bc1a9e5aff95f04'},
#    {'destination': '072dbad57d4e6e32227950da',
#     'duration': 5417,
#     'origin': '105c3a32b2007a715daf7c56'},
#    {'destination': 'ce6feed06bc1a9e5aff95f04',
#     'duration': 5319,
#     'origin': '072dbad57d4e6e32227950da'}],
#   'truck_id': '8386WZB'},
#  {'items': ['14',
#    '15',
#    '16',
#    '0',
#    '74',
#    '75',
#    '34',
#    '28',
#    '29',
#    '30',
#    '31',
#    '23',
#    '39',
#    '40',
#    '67'],
#   'route': [{'destination': 'aa6299b96e163879d9b14a2e',
#     'duration': 532,
#     'origin': 'ce6feed06bc1a9e5aff95f04'},
#    {'destination': '271c4e156a04e84cb99b42e4',
#     'duration': 368,
#     'origin': 'aa6299b96e163879d9b14a2e'},
#    {'destination': '9421632a7121412a1e3cfbf7',
#     'duration': 225,
#     'origin': '271c4e156a04e84cb99b42e4'},
#    {'destination': 'f753ea7ad398e9b1507ca0ad',
#     'duration': 109,
#     'origin': '9421632a7121412a1e3cfbf7'},
#    {'destination': '15937de4acb61e0a344c6f40',
#     'duration': 962,
#     'origin': 'f753ea7ad398e9b1507ca0ad'},
#    {'destination': '35c6bf15e4daff5f3ccc6271',
#     'duration': 1218,
#     'origin': '15937de4acb61e0a344c6f40'},
#    {'destination': 'a204363f4f799fd684bc4c5d',
#     'duration': 1596,
#     'origin': '35c6bf15e4daff5f3ccc6271'},
#    {'destination': '411e46e98c044a75a95d702b',
#     'duration': 171,
#     'origin': 'a204363f4f799fd684bc4c5d'},
#    {'destination': 'ce6feed06bc1a9e5aff95f04',
#     'duration': 416,
#     'origin': '411e46e98c044a75a95d702b'}],
#   'truck_id': '5030LXK'},
#  {'items': ['17',
#    '42',
#    '4',
#    '5',
#    '6',
#    '7',
#    '25',
#    '26',
#    '47',
#    '27',
#    '9',
#    '10',
#    '11',
#    '72',
#    '73',
#    '32',
#    '33',
#    '68',
#    '43',
#    '44',
#    '45',
#    '46',
#    '35',
#    '36',
#    '37',
#    '38'],
#   'route': [{'destination': '5bdef144f209d26c7dbe40da',
#     'duration': 1728,
#     'origin': 'ce6feed06bc1a9e5aff95f04'},
#    {'destination': '99d4795bcb5f957d3bf73757',
#     'duration': 609,
#     'origin': '5bdef144f209d26c7dbe40da'},
#    {'destination': '5aeeca2cdbc6fe31768e2482',
#     'duration': 420,
#     'origin': '99d4795bcb5f957d3bf73757'},
#    {'destination': '6c0b5c67a892c5a498be8de3',
#     'duration': 647,
#     'origin': '5aeeca2cdbc6fe31768e2482'},
#    {'destination': '35a1f25b972649272cfd81bb',
#     'duration': 534,
#     'origin': '6c0b5c67a892c5a498be8de3'},
#    {'destination': '502e8d84cab29327b2793d0c',
#     'duration': 408,
#     'origin': '35a1f25b972649272cfd81bb'},
#    {'destination': 'f94e169f0b12ae653f3b3a40',
#     'duration': 948,
#     'origin': '502e8d84cab29327b2793d0c'},
#    {'destination': '103daf6394133e32f804e175',
#     'duration': 1112,
#     'origin': 'f94e169f0b12ae653f3b3a40'},
#    {'destination': 'd96022d61e3dce588da13a80',
#     'duration': 1026,
#     'origin': '103daf6394133e32f804e175'},
#    {'destination': '18bbf5d95bfd24e10d0276ed',
#     'duration': 1175,
#     'origin': 'd96022d61e3dce588da13a80'},
#    {'destination': '46ec743070ee06552b3c2ccd',
#     'duration': 270,
#     'origin': '18bbf5d95bfd24e10d0276ed'},
#    {'destination': 'bad1346113ee6654c4bd2162',
#     'duration': 618,
#     'origin': '46ec743070ee06552b3c2ccd'},
#    {'destination': 'ce6feed06bc1a9e5aff95f04',
#     'duration': 540,
#     'origin': 'bad1346113ee6654c4bd2162'}],
#   'truck_id': '3321FBL'},
#  {'items': ['1', '2', '3', '76', '77', '78', '79', '19', '20', '12', '13'],
#   'route': [{'destination': 'beb9ae6f854d9e37923a4408',
#     'duration': 791,
#     'origin': 'ce6feed06bc1a9e5aff95f04'},
#    {'destination': 'b704f0e5c30fca37b8fe1758',
#     'duration': 210,
#     'origin': 'beb9ae6f854d9e37923a4408'},
#    {'destination': '12bb64cd1cdfddcd2fabcae3',
#     'duration': 297,
#     'origin': 'b704f0e5c30fca37b8fe1758'},
#    {'destination': '0fc4c56e83b88388a1f6fad2',
#     'duration': 651,
#     'origin': '12bb64cd1cdfddcd2fabcae3'},
#    {'destination': 'ce6feed06bc1a9e5aff95f04',
#     'duration': 412,
#     'origin': '0fc4c56e83b88388a1f6fad2'}],
#   'truck_id': '0013DYS'}]

# %%
events.groupby(events["eventType"]).count()
# Out:
#                           eventDescription  eventTime  simulationId  truckId
# eventType
# Truck arrived                         3444       3444          3444     3444
# Truck departed                        3444       3444          3444     3444
# Truck departed to depot                640        640           640      640
# Truck ended delivering                8567       8567          8567     8567
# Truck ended route                      640        640           640      640
# Truck initialized                      640        640           640      640
# Truck received packets                 640        640           640      640
# Truck started delivering              8567       8567          8567     8567

# %% [markdown]
# ## Tiempos de entrega

# %%
entregas = events[events.eventType.isin(["Truck ended delivering", "Truck started delivering"])]
entregas = entregas.sort_values("eventType",ascending=True)
entregas = entregas.sort_values(by=["simulationId", "truckId", "eventTime"])

# %%
entregas["deliverTime"] = entregas["eventTime"].diff()
entregas = entregas[entregas.eventType == "Truck ended delivering"]
entregas
# Out:
#                                         eventDescription  eventTime  \
# 13021  Packet 78 to (calle del Poeta Blas de Otero, 2...     872250
# 13112  Packet 79 to (calle del Poeta Blas de Otero, 2...     992820
# 13566  Packet 50 to (calle de Valdecanillas, 59, Madr...    1536120
# 13614  Packet 51 to (calle de Valdecanillas, 59, Madr...    1596720
# 13666  Packet 52 to (calle de Valdecanillas, 59, Madr...    1657320
# ...                                                  ...        ...
# 11113  Packet 42 to (calle de la Comunidad de Madrid,...    7565580
# 11176  Packet 43 to (calle de la Comunidad de Madrid,...    7626180
# 11655  Packet 79 to (calle San Andrés, 21, Majadahond...    8243580
# 11729  Packet 80 to (calle San Andrés, 21, Majadahond...    8304180
# 11786  Packet 81 to (calle San Andrés, 21, Majadahond...    8364780
#
#                     eventType                          simulationId  truckId  \
# 13021  Truck ended delivering  007f3d08-14a7-4a93-af9e-f0d9cfbcea94  3321FBL
# 13112  Truck ended delivering  007f3d08-14a7-4a93-af9e-f0d9cfbcea94  3321FBL
# 13566  Truck ended delivering  007f3d08-14a7-4a93-af9e-f0d9cfbcea94  3321FBL
# 13614  Truck ended delivering  007f3d08-14a7-4a93-af9e-f0d9cfbcea94  3321FBL
# 13666  Truck ended delivering  007f3d08-14a7-4a93-af9e-f0d9cfbcea94  3321FBL
# ...                       ...                                   ...      ...
# 11113  Truck ended delivering  fea13535-ade6-4215-96ca-dab5b4ef309b  6965XLY
# 11176  Truck ended delivering  fea13535-ade6-4215-96ca-dab5b4ef309b  6965XLY
# 11655  Truck ended delivering  fea13535-ade6-4215-96ca-dab5b4ef309b  6965XLY
# 11729  Truck ended delivering  fea13535-ade6-4215-96ca-dab5b4ef309b  6965XLY
# 11786  Truck ended delivering  fea13535-ade6-4215-96ca-dab5b4ef309b  6965XLY
#
#        deliverTime
# 13021     120630.0
# 13112     120570.0
# 13566      60600.0
# 13614      60600.0
# 13666      60600.0
# ...            ...
# 11113      60600.0
# 11176      60570.0
# 11655      60600.0
# 11729      60600.0
# 11786      60600.0
#
# [8567 rows x 6 columns]

# %%
events["eventType"].value_counts()
# Out:
# eventType
# Truck started delivering    8567
# Truck ended delivering      8567
# Truck departed              3444
# Truck arrived               3444
# Truck initialized            640
# Truck received packets       640
# Truck departed to depot      640
# Truck ended route            640
# Name: count, dtype: int64

# %% [markdown]
# ## Desanidar los planes

# %%
planes
# Out:
#                                                 items  \
# 0   [{'itemId': '0', 'locationId': '326ae8dc7810de...
# 1   [{'itemId': '0', 'locationId': '271c4e156a04e8...
# 2   [{'itemId': '0', 'locationId': '6aa95e84c67637...
# 3   [{'itemId': '0', 'locationId': '0078f3bf6db092...
# 4   [{'itemId': '0', 'locationId': '92e059821c9ca8...
# ..                                                ...
# 94  [{'itemId': '0', 'locationId': '281ec8ac82cccd...
# 95  [{'itemId': '0', 'locationId': '950001b613cb58...
# 96  [{'itemId': '0', 'locationId': 'b40599012e4fba...
# 97  [{'itemId': '0', 'locationId': '074dc13529fd8b...
# 98  [{'itemId': '0', 'locationId': 'd1214b27823e6d...
#
#                             simulationId  \
# 0   a2bfd344-3b14-462a-82e7-d42aca54a650
# 1   a8a11526-6b9b-4143-bfb1-ffcae600a17e
# 2   2f956e3a-25df-4c5e-bb50-92d92dc9ba00
# 3   45c9a42a-7cb5-4266-b0aa-a05b3f446390
# 4   864bd9f3-074d-45e8-a032-5a01237ae290
# ..                                   ...
# 94  81acb266-ab82-497b-92d9-fae490cc4823
# 95  f007019f-866d-48be-a0cb-bd96328ee43b
# 96  f0f90050-5a0f-4965-864e-d6bc0d02b5a0
# 97  e33505ca-bfdb-496f-bcfd-b8b913a42637
# 98  6deec7b7-6c11-418c-a1bd-f99a9e3261b6
#
#                                                trucks
# 0   [{'items': ['23', '24', '4', '25', '26', '27',...
# 1   [{'items': ['62', '63', '69', '70', '71', '21'...
# 2   [{'items': ['79', '20', '21', '5', '76', '59',...
# 3   [{'items': ['3', '4', '5', '6', '72', '11', '1...
# 4   [{'items': ['77', '78', '79', '16', '17', '91'...
# ..                                                ...
# 94  [{'items': ['36', '37', '49', '6', '7', '8', '...
# 95  [{'items': ['46', '47', '48', '49', '40', '24'...
# 96  [{'items': ['16', '17', '42', '43', '44', '45'...
# 97  [{'items': ['62', '63', '64', '86', '10', '11'...
# 98  [{'items': ['53', '54', '55', '83', '84', '85'...
#
# [99 rows x 3 columns]

# %%
pd.DataFrame(planes.trucks[0])
# Out:
#                                                items  \
# 0  [23, 24, 4, 25, 26, 27, 28, 40, 41, 42, 43, 13...
# 1  [74, 75, 76, 67, 68, 69, 70, 92, 93, 94, 55, 5...
# 2  [18, 19, 57, 58, 88, 89, 90, 91, 54, 20, 21, 2...
# 3                   [87, 0, 1, 2, 3, 33, 95, 96, 97]
# 4                           [31, 32, 37, 38, 39, 66]
# 5                                               [86]
# 6  [77, 78, 79, 52, 53, 29, 30, 80, 81, 82, 34, 3...
#
#                                                route truck_id
# 0  [{'destination': 'af3ea5c0e98151a51bd39c64', '...  5534TPH
# 1  [{'destination': 'faf06210580833f8c7963506', '...  2423VRT
# 2  [{'destination': 'bef2df0471ee1c26b4ab6ba9', '...  0265TYL
# 3  [{'destination': '7a249403ad22a72495769f75', '...  8809GPH
# 4  [{'destination': '1e38734ff239ccf75bf04b95', '...  1161GJN
# 5  [{'destination': '7d1544d169eeeb1d917e9f02', '...  1669HSZ
# 6  [{'destination': '166c008321c564cf6c885cb2', '...  3321FBL

# %%
pd.DataFrame(pd.DataFrame(planes.trucks[0]).route[0])
# Out:
#                 destination  duration                    origin
# 0  af3ea5c0e98151a51bd39c64       197  ce6feed06bc1a9e5aff95f04
# 1  c0430d1e19c34a06e343a270       733  af3ea5c0e98151a51bd39c64
# 2  b31f6bb5c55435cb5495a62b       380  c0430d1e19c34a06e343a270
# 3  58a50ddf91095c052e330fd6       612  b31f6bb5c55435cb5495a62b
# 4  910cd4ad38bc68ff7abdd941       850  58a50ddf91095c052e330fd6
# 5  49a09d201cc830dc1c4e87fc       241  910cd4ad38bc68ff7abdd941
# 6  324beca4107779629830c6d3       689  49a09d201cc830dc1c4e87fc
# 7  123039c250dd5a3e7c3e4fc8       187  324beca4107779629830c6d3
# 8  5a13a4517d5fc3018de2dbea      1203  123039c250dd5a3e7c3e4fc8
# 9  ce6feed06bc1a9e5aff95f04        99  5a13a4517d5fc3018de2dbea

# %%
planes_desanidado = planes.join(planes.trucks.explode().apply(pd.Series), lsuffix='_planes').reset_index(drop=True)
planes_desanidado
# Out:
#                                           items_planes  \
# 0    [{'itemId': '0', 'locationId': '326ae8dc7810de...
# 1    [{'itemId': '0', 'locationId': '326ae8dc7810de...
# 2    [{'itemId': '0', 'locationId': '326ae8dc7810de...
# 3    [{'itemId': '0', 'locationId': '326ae8dc7810de...
# 4    [{'itemId': '0', 'locationId': '326ae8dc7810de...
# ..                                                 ...
# 635  [{'itemId': '0', 'locationId': 'd1214b27823e6d...
# 636  [{'itemId': '0', 'locationId': 'd1214b27823e6d...
# 637  [{'itemId': '0', 'locationId': 'd1214b27823e6d...
# 638  [{'itemId': '0', 'locationId': 'd1214b27823e6d...
# 639  [{'itemId': '0', 'locationId': 'd1214b27823e6d...
#
#                              simulationId  \
# 0    a2bfd344-3b14-462a-82e7-d42aca54a650
# 1    a2bfd344-3b14-462a-82e7-d42aca54a650
# 2    a2bfd344-3b14-462a-82e7-d42aca54a650
# 3    a2bfd344-3b14-462a-82e7-d42aca54a650
# 4    a2bfd344-3b14-462a-82e7-d42aca54a650
# ..                                    ...
# 635  6deec7b7-6c11-418c-a1bd-f99a9e3261b6
# 636  6deec7b7-6c11-418c-a1bd-f99a9e3261b6
# 637  6deec7b7-6c11-418c-a1bd-f99a9e3261b6
# 638  6deec7b7-6c11-418c-a1bd-f99a9e3261b6
# 639  6deec7b7-6c11-418c-a1bd-f99a9e3261b6
#
#                                                 trucks  \
# 0    [{'items': ['23', '24', '4', '25', '26', '27',...
# 1    [{'items': ['23', '24', '4', '25', '26', '27',...
# 2    [{'items': ['23', '24', '4', '25', '26', '27',...
# 3    [{'items': ['23', '24', '4', '25', '26', '27',...
# 4    [{'items': ['23', '24', '4', '25', '26', '27',...
# ..                                                 ...
# 635  [{'items': ['53', '54', '55', '83', '84', '85'...
# 636  [{'items': ['53', '54', '55', '83', '84', '85'...
# 637  [{'items': ['53', '54', '55', '83', '84', '85'...
# 638  [{'items': ['53', '54', '55', '83', '84', '85'...
# 639  [{'items': ['53', '54', '55', '83', '84', '85'...
#
#                                                  items  \
# 0    [23, 24, 4, 25, 26, 27, 28, 40, 41, 42, 43, 13...
# 1    [74, 75, 76, 67, 68, 69, 70, 92, 93, 94, 55, 5...
# 2    [18, 19, 57, 58, 88, 89, 90, 91, 54, 20, 21, 2...
# 3                     [87, 0, 1, 2, 3, 33, 95, 96, 97]
# 4                             [31, 32, 37, 38, 39, 66]
# ..                                                 ...
# 635  [53, 54, 55, 83, 84, 85, 86, 26, 27, 29, 30, 3...
# 636  [72, 73, 74, 88, 89, 90, 91, 43, 62, 63, 64, 3...
# 637                                       [6, 7, 8, 9]
# 638  [44, 45, 46, 47, 94, 20, 21, 22, 95, 96, 97, 6...
# 639  [79, 80, 81, 82, 24, 25, 40, 41, 42, 12, 23, 9...
#
#                                                  route truck_id
# 0    [{'destination': 'af3ea5c0e98151a51bd39c64', '...  5534TPH
# 1    [{'destination': 'faf06210580833f8c7963506', '...  2423VRT
# 2    [{'destination': 'bef2df0471ee1c26b4ab6ba9', '...  0265TYL
# 3    [{'destination': '7a249403ad22a72495769f75', '...  8809GPH
# 4    [{'destination': '1e38734ff239ccf75bf04b95', '...  1161GJN
# ..                                                 ...      ...
# 635  [{'destination': '225cd814768e8ca390983313', '...  5534TPH
# 636  [{'destination': '417bf3aae83127cd905f3bc9', '...  3953RLD
# 637  [{'destination': '1e1251e186dd507f63e4d1e6', '...  5030LXK
# 638  [{'destination': '6a33d0bcd3624ccb86febf09', '...  3321FBL
# 639  [{'destination': '17c23e21622baec6f08861dd', '...  6270NFM
#
# [640 rows x 6 columns]

# %%
planes_desanidado_x2 = planes_desanidado.join(planes_desanidado.route.explode().apply(pd.Series)).reset_index(drop=True)
planes_desanidado_x2[['simulationId', 'truck_id', 'origin', 'destination', 'duration']]
# Out:
#                               simulationId truck_id                    origin  \
# 0     a2bfd344-3b14-462a-82e7-d42aca54a650  5534TPH  ce6feed06bc1a9e5aff95f04
# 1     a2bfd344-3b14-462a-82e7-d42aca54a650  5534TPH  af3ea5c0e98151a51bd39c64
# 2     a2bfd344-3b14-462a-82e7-d42aca54a650  5534TPH  c0430d1e19c34a06e343a270
# 3     a2bfd344-3b14-462a-82e7-d42aca54a650  5534TPH  b31f6bb5c55435cb5495a62b
# 4     a2bfd344-3b14-462a-82e7-d42aca54a650  5534TPH  58a50ddf91095c052e330fd6
# ...                                    ...      ...                       ...
# 4079  6deec7b7-6c11-418c-a1bd-f99a9e3261b6  6270NFM  20ee036e147b4a1bd5af0e1c
# 4080  6deec7b7-6c11-418c-a1bd-f99a9e3261b6  6270NFM  5bec37aee4796cc965e71c88
# 4081  6deec7b7-6c11-418c-a1bd-f99a9e3261b6  6270NFM  1f183bd64aa5bfae47843de5
# 4082  6deec7b7-6c11-418c-a1bd-f99a9e3261b6  6270NFM  4551fdc303a5ddafa1dcf28c
# 4083  6deec7b7-6c11-418c-a1bd-f99a9e3261b6  6270NFM  2884f6b369dc20f3051a216d
#
#                    destination  duration
# 0     af3ea5c0e98151a51bd39c64       197
# 1     c0430d1e19c34a06e343a270       733
# 2     b31f6bb5c55435cb5495a62b       380
# 3     58a50ddf91095c052e330fd6       612
# 4     910cd4ad38bc68ff7abdd941       850
# ...                        ...       ...
# 4079  5bec37aee4796cc965e71c88      1173
# 4080  1f183bd64aa5bfae47843de5      1198
# 4081  4551fdc303a5ddafa1dcf28c      1133
# 4082  2884f6b369dc20f3051a216d       804
# 4083  ce6feed06bc1a9e5aff95f04       750
#
# [4084 rows x 5 columns]

# %%
planes_desanidado_x2.sort_values(by=["simulationId", "truck_id"], inplace=True)

# %%
primer_nivel =

# %%
segundo_nivel = primer_nivel.join(primer_nivel.route.explode().apply)

# %%
events.eventType.isin(["Truck departed", "Truck arrived", "Truck departed to depot", ""])
viajes = viajes.sort_values(by=["simulationId", "truckId", "eventTime"])
viajes["delta"] = viajes.eventTime.diff(1)
